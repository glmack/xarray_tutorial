# %% [markdown]
# # Plotting and Visualization
#
# Labeled data enables expressive computations. These same labels can also be used to easily create informative plots.
#
# xarray plotting functionality is a thin wrapper around the popular matplotlib library. Matplotlib syntax and function names were copied as much as possible, which makes for an easy transition between the two.
#
# ### Outline
# - Matplotlib Integration
# - Maps using Cartopy
# - Extensions using Bokeh/Holoviews/Geoviews
#
# ### Tutorial Duriation
# 10 minutes
#
# ### Going Further
#
# Xarray's Documentation on Plotting: http://xarray.pydata.org/en/latest/plotting.htm

# %%
# uncomment to install cartopy and geoviews
# ! pip install cartopy
# ! pip install --no-use-pep517 cartopy
# ! pip install Cartopy==0.16.0

# ! pip install geoviews

# %%
# uncomment to pip install holoviews and geoviews
# ! pip install holoviews
# Out:
# Collecting geoviews
#   Downloading https://files.pythonhosted.org/packages/3d/4d/a0fb8e68e75f6bbdaa8a4804a0ab2176680c70d27168bcf832a10f349263/geoviews-1.6.3-py2.py3-none-any.whl (427kB)
#      |████████████████████████████████| 430kB 2.4MB/s eta 0:00:01     |████████████▎                   | 163kB 2.4MB/s eta 0:00:01
# Requirement already satisfied: param>=1.6.1 in /anaconda3/lib/python3.6/site-packages (from geoviews) (1.9.1)
# Requirement already satisfied: numpy>=1.0 in /anaconda3/lib/python3.6/site-packages (from geoviews) (1.16.4)
# Requirement already satisfied: holoviews>=1.11.1 in /anaconda3/lib/python3.6/site-packages (from geoviews) (1.12.5)
# Collecting bokeh>=1.0.0 (from geoviews)
#   Downloading https://files.pythonhosted.org/packages/89/25/a07183dd96ca22dafe429254985cbf8241ccd35730c5568d6502b3bc6bb7/bokeh-1.3.4.tar.gz (17.8MB)
#      |████████████████████████████████| 17.8MB 6.4MB/s eta 0:00:01
# Collecting cartopy>=0.16.0 (from geoviews)
#   Using cached https://files.pythonhosted.org/packages/e5/92/fe8838fa8158931906dfc4f16c5c1436b3dd2daf83592645b179581403ad/Cartopy-0.17.0.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pyviz-comms>=0.7.2 in /anaconda3/lib/python3.6/site-packages (from holoviews>=1.11.1->geoviews) (0.7.2)
# Requirement already satisfied: six>=1.5.2 in /anaconda3/lib/python3.6/site-packages (from bokeh>=1.0.0->geoviews) (1.11.0)
# Requirement already satisfied: PyYAML>=3.10 in /anaconda3/lib/python3.6/site-packages (from bokeh>=1.0.0->geoviews) (3.12)
# Requirement already satisfied: python-dateutil>=2.1 in /anaconda3/lib/python3.6/site-packages (from bokeh>=1.0.0->geoviews) (2.7.3)
# Requirement already satisfied: Jinja2>=2.7 in /anaconda3/lib/python3.6/site-packages (from bokeh>=1.0.0->geoviews) (2.10)
# Requirement already satisfied: pillow>=4.0 in /anaconda3/lib/python3.6/site-packages (from bokeh>=1.0.0->geoviews) (5.1.0)
# Requirement already satisfied: packaging>=16.8 in /anaconda3/lib/python3.6/site-packages (from bokeh>=1.0.0->geoviews) (17.1)
# Requirement already satisfied: tornado>=4.3 in /anaconda3/lib/python3.6/site-packages (from bokeh>=1.0.0->geoviews) (5.0.2)
# Requirement already satisfied: setuptools>=0.7.2 in /anaconda3/lib/python3.6/site-packages (from cartopy>=0.16.0->geoviews) (41.0.1)
# Requirement already satisfied: shapely>=1.5.6 in /anaconda3/lib/python3.6/site-packages (from cartopy>=0.16.0->geoviews) (1.6.4.post2)
# Requirement already satisfied: pyshp>=1.1.4 in /anaconda3/lib/python3.6/site-packages (from cartopy>=0.16.0->geoviews) (2.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/lib/python3.6/site-packages (from Jinja2>=2.7->bokeh>=1.0.0->geoviews) (1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /anaconda3/lib/python3.6/site-packages (from packaging>=16.8->bokeh>=1.0.0->geoviews) (2.2.0)
# Building wheels for collected packages: cartopy
#   Building wheel for cartopy (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /anaconda3/bin/python /anaconda3/lib/python3.6/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/6g/27zvvxsd0v12h5nfky3vldz00000gn/T/tmpwbr_vgej
#        cwd: /private/var/folders/6g/27zvvxsd0v12h5nfky3vldz00000gn/T/pip-install-bhxrpexg/cartopy
#   Complete output (259 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.7-x86_64-3.6
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy
#   copying lib/cartopy/_version.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy
#   copying lib/cartopy/_epsg.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy
#   copying lib/cartopy/util.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy
#   copying lib/cartopy/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy
#   copying lib/cartopy/crs.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy
#   copying lib/cartopy/img_transform.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy
#   copying lib/cartopy/vector_transform.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/sphinxext
#   copying lib/cartopy/sphinxext/summarise_package.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/sphinxext
#   copying lib/cartopy/sphinxext/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/sphinxext
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/io
#   copying lib/cartopy/io/img_tiles.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/io
#   copying lib/cartopy/io/shapereader.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/io
#   copying lib/cartopy/io/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/io
#   copying lib/cartopy/io/img_nest.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/io
#   copying lib/cartopy/io/srtm.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/io
#   copying lib/cartopy/io/ogc_clients.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/io
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_features.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_coding_standards.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_img_nest.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_coastline.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_geodesic.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_shapereader.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_vector_transform.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_line_string.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_util.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_crs_transform_vectors.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_polygon.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_linear_ring.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_img_tiles.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_img_transform.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   copying lib/cartopy/tests/test_crs.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/geodesic
#   copying lib/cartopy/geodesic/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/geodesic
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/un_flag.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/star_shaped_boundary.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/tick_labels.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/arrows.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/tube_stations.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/effects_of_the_ellipse.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/tissot.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/favicon.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/feature_creation.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/eccentric_ellipse.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/features.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/wmts.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/eyja_volcano.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/geostationary.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/hurricane_katrina.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/wms.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/regridding_arrows.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/logo.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/rotated_pole.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/global_map.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/utm_all_zones.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/always_circular_stereo.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/aurora_forecast.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/waves.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/image_tiles.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/reprojected_wmts.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/axes_grid_basic.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/wmts_time.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/barbs.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/nightshade.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   copying lib/cartopy/examples/streamplot.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/examples
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/mpl
#   copying lib/cartopy/mpl/patch.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/mpl
#   copying lib/cartopy/mpl/slippy_image_artist.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/mpl
#   copying lib/cartopy/mpl/feature_artist.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/mpl
#   copying lib/cartopy/mpl/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/mpl
#   copying lib/cartopy/mpl/clip_path.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/mpl
#   copying lib/cartopy/mpl/geoaxes.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/mpl
#   copying lib/cartopy/mpl/ticker.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/mpl
#   copying lib/cartopy/mpl/gridliner.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/mpl
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/feature
#   copying lib/cartopy/feature/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/feature
#   copying lib/cartopy/feature/nightshade.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/feature
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/io
#   copying lib/cartopy/tests/io/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/io
#   copying lib/cartopy/tests/io/test_downloaders.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/io
#   copying lib/cartopy/tests/io/test_ogc_clients.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/io
#   copying lib/cartopy/tests/io/test_srtm.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/io
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_plots.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_features.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_images.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_set_extent.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_nightshade.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_shapely_to_mpl.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_gridliner.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_ticker.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_patch.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_quiver.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_img_transform.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_web_services.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_caching.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_crs.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_contour.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_ticks.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_axes.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_pseudo_color.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_examples.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_feature_artist.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_mpl_integration.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/feature
#   copying lib/cartopy/tests/feature/test_nightshade.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/feature
#   copying lib/cartopy/tests/feature/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/feature
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_orthographic.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_eckert.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_robinson.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_mercator.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_rotated_geodetic.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_geostationary.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_rotated_pole.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_sinusoidal.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_equidistant_conic.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_nearside_perspective.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/__init__.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_miller.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_mollweide.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_interrupted_goode_homolosine.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_lambert_conformal.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_lambert_azimuthal_equal_area.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_transverse_mercator.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_equal_earth.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_utm.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_albers_equal_area.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_azimuthal_equidistant.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_gnomonic.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_stereographic.py -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/crs
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_ticks/xticks_no_transform.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_ticks/yticks_cylindrical.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_ticks/xyticks.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_ticks/yticks_no_transform.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_ticks/xticks_cylindrical.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_images
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_images/imshow_natural_earth_ortho.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_images
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_images/image_nest.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_images
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_images/image_merge.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_images
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_images/web_tiles.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_images
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_images/imshow_regional_projected.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_images
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_web_services
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_web_services/wms.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_web_services
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_web_services/wmts.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_web_services
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/gridliner_labels.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/gridliner1.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/gridliner_labels_1.5.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_img_transform
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_img_transform/regrid_image.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_img_transform
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_shapely_to_mpl
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_shapely_to_mpl/poly_interiors.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_shapely_to_mpl
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_shapely_to_mpl/contour_with_interiors.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_shapely_to_mpl
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_examples
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_examples/global_map.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_examples
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_nightshade
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_nightshade/nightshade_platecarree.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_nightshade
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_img_tiles2
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_img_tiles2/web_tiles.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_img_tiles2
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_crs
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_crs/lambert_conformal_south.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_crs
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_crs/mercator_squashed.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_crs
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_features
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_features/natural_earth_custom.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_features
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_features/gshhs_coastlines.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_features
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_features/wfs.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_features
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_features/natural_earth.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_features
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_goode_wrap.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/quiver_rotated_pole.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/multiple_projections520.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/multiple_projections5.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/quiver_plate_carree.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/streamplot_mpl_2.1.0.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/natural_earth_interface.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/multiple_projections4.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/global_contour_wrap_mpl_pre_3.0.0.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/streamplot_mpl_1.4.3.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/barbs_1d.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/barbs_1d_transformed.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_global_wrap1.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/streamplot_mpl_2.0.0.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_global_wrap2.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_global_wrap3.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/barbs_plate_carree.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/streamplot_mpl_3.0.0.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/global_contour_wrap.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_limited_area_wrap.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_single_column_wrap.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/barbs_regrid.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/quiver_regrid_with_extent.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_mercator_wrap.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/global_map.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/global_scatter_wrap.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/global_contourf_wrap.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/quiver_regrid.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/global_pcolor_wrap.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/simple_global.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/barbs_regrid_with_extent.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/data
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/data/raster
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/data/raster/natural_earth
#   copying lib/cartopy/data/raster/natural_earth/images.json -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/raster/natural_earth
#   copying lib/cartopy/data/raster/natural_earth/50-natural-earth-1-downsampled.png -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/raster/natural_earth
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/data/raster/sample
#   copying lib/cartopy/data/raster/sample/Miriam.A2012270.2050.2km.jpg -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/raster/sample
#   copying lib/cartopy/data/raster/sample/Miriam.A2012270.2050.2km.README.txt -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/raster/sample
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/data/netcdf
#   copying lib/cartopy/data/netcdf/HadISST1_SST_update.README.txt -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/netcdf
#   copying lib/cartopy/data/netcdf/HadISST1_SST_update.nc -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/netcdf
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/data/shapefiles
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/data/shapefiles/gshhs
#   copying lib/cartopy/data/shapefiles/gshhs/README.TXT -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/shapefiles/gshhs
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/data/shapefiles/gshhs/c
#   copying lib/cartopy/data/shapefiles/gshhs/c/GSHHS_c_L1.dbf -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/shapefiles/gshhs/c
#   copying lib/cartopy/data/shapefiles/gshhs/c/GSHHS_c_L1.shx -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/shapefiles/gshhs/c
#   copying lib/cartopy/data/shapefiles/gshhs/c/GSHHS_c_L1.shp -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/shapefiles/gshhs/c
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/data/shapefiles/gshhs/l
#   copying lib/cartopy/data/shapefiles/gshhs/l/GSHHS_l_L2.dbf -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/shapefiles/gshhs/l
#   copying lib/cartopy/data/shapefiles/gshhs/l/GSHHS_l_L2.shp -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/shapefiles/gshhs/l
#   copying lib/cartopy/data/shapefiles/gshhs/l/GSHHS_l_L2.shx -> build/lib.macosx-10.7-x86_64-3.6/cartopy/data/shapefiles/gshhs/l
#   creating build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/lakes_shapefile
#   copying lib/cartopy/tests/lakes_shapefile/ne_110m_lakes.dbf -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/lakes_shapefile
#   copying lib/cartopy/tests/lakes_shapefile/ne_110m_lakes.shp -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/lakes_shapefile
#   copying lib/cartopy/tests/lakes_shapefile/ne_110m_lakes.shx -> build/lib.macosx-10.7-x86_64-3.6/cartopy/tests/lakes_shapefile
#   copying lib/cartopy/io/srtm.npz -> build/lib.macosx-10.7-x86_64-3.6/cartopy/io
#   UPDATING build/lib.macosx-10.7-x86_64-3.6/cartopy/_version.py
#   set build/lib.macosx-10.7-x86_64-3.6/cartopy/_version.py to '0.17.0'
#   running build_ext
#   cythoning lib/cartopy/trace.pyx to lib/cartopy/trace.cpp
#   building 'cartopy.trace' extension
#   creating build/temp.macosx-10.7-x86_64-3.6
#   creating build/temp.macosx-10.7-x86_64-3.6/lib
#   creating build/temp.macosx-10.7-x86_64-3.6/lib/cartopy
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -I/anaconda3/include -I./lib/cartopy -I/anaconda3/include -I/anaconda3/include/python3.6m -c lib/cartopy/trace.cpp -o build/temp.macosx-10.7-x86_64-3.6/lib/cartopy/trace.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   In file included from lib/cartopy/trace.cpp:611:
#   /anaconda3/include/geos_c.h:40:11: fatal error: 'cstddef' file not found
#   # include <cstddef>
#             ^~~~~~~~~
#   1 warning and 1 error generated.
#   /private/var/folders/6g/27zvvxsd0v12h5nfky3vldz00000gn/T/pip-build-env-5834h64m/overlay/lib/python3.6/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/6g/27zvvxsd0v12h5nfky3vldz00000gn/T/pip-install-bhxrpexg/cartopy/lib/cartopy/trace.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   error: command 'gcc' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for cartopy
#   Running setup.py clean for cartopy
# Failed to build cartopy
# Building wheels for collected packages: bokeh
#   Building wheel for bokeh (setup.py) ... done
#   Created wheel for bokeh: filename=bokeh-1.3.4-cp36-none-any.whl size=8545228 sha256=842bda93f2623bb30d157fcb62ac2a2c5c01219a9e00d3bd2a571ac5703bab05
#   Stored in directory: /Users/lee/Library/Caches/pip/wheels/a7/df/f1/80f108cd241803a5200576ac0eed112f0acea5582575cf08b6
# Successfully built bokeh
# ERROR: Could not build wheels for cartopy which use PEP 517 and cannot be installed directly

# %%
# %matplotlib inline

import xarray as xr
import matplotlib.pyplot as plt

# load some tutorial data
ds = xr.tutorial.load_dataset('air_temperature')

# %% [markdown]
# ## Plotting 1d data

# %%
da_point_resample = ds['air'].isel(lat=20, lon=40).resample(time='1D')

t_max = da_point_resample.max('time')
t_min = da_point_resample.min('time')
t_max.plot(label='t_max')
t_min.plot(label='t_min')
plt.legend()

# %% [markdown]
# ## Plotting 2d Data

# %%
t_mean = ds['air'].mean('time')

t_mean.plot()

# %% [markdown]
# ## Plotting >2d Data

# %%
ds['air'].plot()
# Out:
# (array([   2182.,   60537.,  195026.,  233763.,  315219.,  635948.,
#          778807., 1192236.,  453381.,    1901.]),
#  array([221.     , 230.64   , 240.28   , 249.92   , 259.56   , 269.2    ,
#         278.84   , 288.47998, 298.12   , 307.76   , 317.4    ],
#        dtype=float32),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## FacetGrid Plots

# %%
# Calculate some seasonal anomalies

da_month = ds['air'].resample(time='QS-Dec').mean('time')

climatology = da_month.groupby('time.season').mean('time')
anomalies = da_month.groupby('time.season') - climatology
anomalies
# Out:
# <xarray.DataArray 'air' (time: 9, lat: 25, lon: 53)>
# array([[[-3.773804, -3.678513, ...,  0.694107,  0.511429],
#         [-3.474045, -3.666229, ...,  0.360214, -0.020752],
#         ...,
#         [-0.704315, -0.852051, ..., -0.583862, -0.642242],
#         [-0.715424, -0.850372, ..., -0.569336, -0.589539]],
#
#        [[-1.346527, -1.386505, ...,  0.275513,  0.253067],
#         [-1.623169, -1.677673, ...,  0.34256 ,  0.185089],
#         ...,
#         [-0.185394, -0.185577, ...,  0.637665,  0.635193],
#         [-0.167633, -0.191406, ...,  0.611938,  0.589539]],
#
#        ...,
#
#        [[ 0.904022,  0.800323, ...,  0.871872,  0.839523],
#         [ 0.238525,  0.049438, ...,  1.4216  ,  1.492126],
#         ...,
#         [ 0.464142,  0.478058, ...,  0.009064, -0.012024],
#         [ 0.452423,  0.437134, ..., -0.037537, -0.024811]],
#
#        [[ 0.332367,  0.4272  , ..., -1.304581, -1.535797],
#         [-0.378113, -0.037628, ..., -1.495529, -1.767532],
#         ...,
#         [ 0.473602,  0.563446, ...,  1.30896 ,  1.416687],
#         [ 0.545227,  0.665039, ...,  1.268372,  1.322388]]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float64 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2012-12-01 2013-03-01 ... 2014-12-01
#     season   (time) <U3 'DJF' 'MAM' 'JJA' 'SON' 'DJF' 'MAM' 'JJA' 'SON' 'DJF'

# %%
anomalies.plot(col='time', col_wrap=4)

# %% [markdown]
# ## Plotting maps using Cartopy

# %%
import cartopy.crs as ccrs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-139fa5ad2567> in <module>()
# ----> 1 import cartopy.crs as ccrs
#
# ModuleNotFoundError: No module named 'cartopy'

# %%
ax = plt.axes(projection=ccrs.Orthographic(-80, 35))
t_mean.plot.contourf(ax=ax, transform=ccrs.PlateCarree())
ax.set_global()
ax.coastlines()

# %% [markdown]
# ## Plotting using Holoviews and Geoviews

# %%
import holoviews as hv
# import geoviews as gv
# import geoviews.feature as gf

hv.notebook_extension()
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
# initialize the holoviews dataset
ds_hv = hv.Dataset(t_mean)
ds_hv
# Out:
# :Dataset   [lat,lon]   (air)

# %%
# make a plot with holoviews
# %opts Image [colorbar=True fig_size=200] (cmap='viridis')
ds_hv.to(hv.Image, ['lon', 'lat'])
# Out:
# :Image   [lon,lat]   (air)

# %%
# repeat the same steps but now use geoviews
# %opts Image [colorbar=True fig_size=200] (cmap='viridis')
ds_hv.to(gv.Image, ['lon', 'lat'], ['air'], ['time']) * gf.coastline()

# %%
# This may require the legacy notebook interface?
# %opts Image [colorbar=True fig_size=200] (cmap='RdBu_r')
ds_hv2 = hv.Dataset(anomalies)
ds_hv2.to(gv.Image, ['lon', 'lat'], ['air'], ['time']) * gf.coastline()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-69a93728e9ed> in <module>()
#       2 get_ipython().run_line_magic('opts', "Image [colorbar=True fig_size=200] (cmap='RdBu_r')")
#       3 ds_hv2 = hv.Dataset(anomalies)
# ----> 4 ds_hv2.to(gv.Image, ['lon', 'lat'], ['air'], ['time']) * gf.coastline()
#
# NameError: name 'gv' is not defined
